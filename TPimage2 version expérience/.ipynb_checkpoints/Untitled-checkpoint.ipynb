# %%
import numpy as np
from math import *
import matplotlib.pyplot as plt
from PIL import Image

I = Image.open('wwf.jpg')
I = np.array(I)
I = I.astype(float)
I

# #added
# I17 = [[0 for k in range(len(I[0]))] for i in range(len(I))]
# for k in range(len(I)) :
#     for i in range(len(I[0])) :
#         avg = 0
#         for e in range(3) :
#             avg += I[k][i][e]
#         I17[k][i] = avg / 3 

# I17 = np.array(I17)
# #added


I17 = np.copy(I)

C = [[0 for j in range (1,len(I17[0]) - 1 )] for k in range (1, len(I17) - 1)]
for k in range (1, len(I17) - 1) :
    for j in range (1, len(I17[0]) - 1 ) :
        dx = ( I17[k,j+1] - I17[k,j-1] ) / 2
        dy = ( I17[k+1,j] - I17[k-1,j] ) / 2 
        C[k - 1][j - 1] = sqrt(dx*dx + dy*dy)


plt.imshow(C,cmap='gray')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-7099af4bccaa> in <module>
#      29         dx = ( I17[k,j+1] - I17[k,j-1] ) / 2
#      30         dy = ( I17[k+1,j] - I17[k-1,j] ) / 2
# ---> 31         C[k - 1][j - 1] = sqrt(dx*dx + dy*dy)
#      32
#      33
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
C1 = np.copy(C)

for l in range(len(C)) :
    for c in range(len(C[0])) :
        C1[l][C1[l] < 10] = 0
        C1[l][C1[l] > 10] = 120
        
plt.imshow(C1,cmap='gray')
plt.colorbar()

# %%
def Methode_des_cercles(M,val_dec,start_l, start_c) :
    nb_de_points = 0
    for l in range(len(M)) :
        for c in range(len(M[0])) :
            if (M[l][c] == val_dec):
                nb_de_points += 1

    traj = []
    points_restant = nb_de_points
    pivot_coordonnées = (start_l,start_c)
    while(points_restant > 0) :
        print(str(100 - (points_restant/nb_de_points)*100)+"pourcent effectué")
        traj.append(pivot_coordonnées)
        pivot_coordonnées = plus_proche_voisin(M,pivot_coordonnées, val_dec)
        points_restant -= 1
        M[pivot_coordonnées[0]][pivot_coordonnées[1]] = 0 #mis à 0 parce qu'il n'est plus à traité
    for couple in traj :
        print("{x : "+str(couple[1] - len(M[0])//2)+", y : "+str(couple[0] - len(M)//2)+"},")


def plus_proche_voisin(M,coordonnées_point, val_dec) : #val dec = la valeur des points qu'on recherche (!= 0)
    n = 1
    not_found = True 
    while(not_found) :
        for l in squareRange(coordonnées_point,n,M)[0] :
            for c in squareRange(coordonnées_point,n,M)[1] :
                if ( n == abs((coordonnées_point[0] - l)) + abs((coordonnées_point[1] - c)) ) :
                    if (M[l][c] == val_dec):
                        not_found = False
                        return (l,c)
        n += 1
        #print(n)

def squareRange(coordonnées_point,n,M) :
    # l doit aller de max(0,coordonnées_point[0] - n) à min(len(M),coordonnées_point[0] + n)
    L = [i for i in range(max(0,coordonnées_point[0] - n), min(len(M),coordonnées_point[0] + n))]
    # c doit aller de max(0,coordonnées_point[1] - n) à min(len(M[0]),coordonnées_point[1] + n)
    C = [i for i in range(max(0,coordonnées_point[1] - n), min(len(M[0]),coordonnées_point[1] + n))]
    return L,C

# def printedtraj(M,val_dec,start_l, start_c) :
#     traj = Methode_des_cercles(M,val_dec,start_l, start_c) 
#     for couple in traj :
#         print("{x : "+str(couple[0])+", y : "+str(couple[1])+"},")

# %%
Methode_des_cercles(C1,120,0,0)
# Out:
# 0.0pourcent effectué
# 0.020193861066232444pourcent effectué
# 0.0403877221324791pourcent effectué
# 0.06058158319871154pourcent effectué
# 0.08077544426494399pourcent effectué
# 0.10096930533117643pourcent effectué
# 0.12116316639742308pourcent effectué
# 0.14135702746365553pourcent effectué
# 0.16155088852988797pourcent effectué
# 0.18174474959612041pourcent effectué
# 0.20193861066235286pourcent effectué
# 0.2221324717285995pourcent effectué
# 0.24232633279483196pourcent effectué
# 0.2625201938610644pourcent effectué
# 0.28271405492729684pourcent effectué
# 0.3029079159935293pourcent effectué
# 0.32310177705977594pourcent effectué
# 0.3432956381260084pourcent effectué
# 0.36348949919225504pourcent effectué
# 0.38368336025847327pourcent effectué
# 0.4038772213247199pourcent effectué
# 0.42407108239095237pourcent effectué
# 0.4442649434571848pourcent effectué
# 0.46445880452343147pourcent effectué
# 0.4846526655896639pourcent effectué
# 0.5048465266558964pourcent effectué
# 0.5250403877221288pourcent effectué
# 0.5452342487883755pourcent effectué
# 0.5654281098546079pourcent effectué
# 0.5856219709208403pourcent effectué
# 0.6058158319870728pourcent effectué
# 0.6260096930533052pourcent effectué
# 0.6462035541195519pourcent effectué
# 0.6663974151857843pourcent effectué
# 0.686591276252031pourcent effectué
# 0.7067851373182492pourcent effectué
# 0.7269789983844817pourcent effectué
# 0.7471728594507283pourcent effectué
# 0.7673667205169608pourcent effectué
# 0.7875605815832074pourcent effectué
# 0.8077544426494399pourcent effectué
# 0.8279483037156723pourcent effectué
# 0.8481421647819047pourcent effectué
# 0.8683360258481372pourcent effectué
# 0.8885298869143838pourcent effectué
# 0.9087237479806163pourcent effectué
# 0.9289176090468487pourcent effectué
# 0.9491114701130812pourcent effectué
# 0.9693053311793278pourcent effectué
# 0.9894991922455603pourcent effectué
# 1.0096930533117927pourcent effectué
# 1.0298869143780252pourcent effectué
# 1.0500807754442576pourcent effectué
# 1.0702746365105043pourcent effectué
# 1.0904684975767367pourcent effectué
# 1.1106623586429833pourcent effectué
# 1.1308562197092158pourcent effectué
# 1.151050080775434pourcent effectué
# 1.1712439418416807pourcent effectué
# 1.1914378029079131pourcent effectué
# 1.2116316639741598pourcent effectué
# 1.2318255250403922pourcent effectué
# 1.2520193861066247pourcent effectué
# 1.272213247172857pourcent effectué
# 1.2924071082390896pourcent effectué
# 1.3126009693053362pourcent effectué
# 1.3327948303715687pourcent effectué
# 1.352988691437801pourcent effectué
# 1.3731825525040335pourcent effectué
# 1.3933764135702802pourcent effectué
# 1.4135702746365126pourcent effectué
# 1.433764135702745pourcent effectué
# 1.4539579967689775pourcent effectué
# 1.47415185783521pourcent effectué
# 1.4943457189014566pourcent effectué
# 1.514539579967689pourcent effectué
# 1.5347334410339357pourcent effectué
# 1.5549273021001682pourcent effectué
# 1.5751211631663864pourcent effectué
# 1.595315024232633pourcent effectué
# 1.6155088852988655pourcent effectué
# 1.6357027463651121pourcent effectué
# 1.6558966074313446pourcent effectué
# 1.676090468497577pourcent effectué
# 1.6962843295638095pourcent effectué
# 1.716478190630042pourcent effectué
# 1.7366720516962886pourcent effectué
# 1.756865912762521pourcent effectué
# 1.7770597738287535pourcent effectué
# 1.797253634894986pourcent effectué
# 1.8174474959612326pourcent effectué
# 1.837641357027465pourcent effectué
# 1.8578352180936974pourcent effectué
# 1.878029079159944pourcent effectué
# 1.8982229402261623pourcent effectué
# 1.918416801292409pourcent effectué
# 1.9386106623586414pourcent effectué
# 1.958804523424888pourcent effectué
# 1.9789983844911205pourcent effectué
# 1.999192245557353pourcent effectué
# 2.0193861066235854pourcent effectué
# 2.039579967689818pourcent effectué
# 2.0597738287560645pourcent effectué
# 2.079967689822297pourcent effectué
# 2.1001615508885294pourcent effectué
# 2.120355411954762pourcent effectué
# 2.1405492730209943pourcent effectué
# 2.160743134087241pourcent effectué
# 2.1809369951534734pourcent effectué
# 2.20113085621972pourcent effectué
# 2.2213247172859383pourcent effectué
# 2.241518578352185pourcent effectué
# 2.2617124394184174pourcent effectué
# 2.28190630048465pourcent effectué
# 2.3021001615508965pourcent effectué
# 2.3222940226171147pourcent effectué
# 2.3424878836833614pourcent effectué
# 2.362681744749594pourcent effectué
# 2.3828756058158405pourcent effectué
# 2.403069466882073pourcent effectué
# 2.4232633279483053pourcent effectué
# 2.443457189014538pourcent effectué
# 2.4636510500807702pourcent effectué
# 2.483844911147017pourcent effectué
# 2.5040387722132493pourcent effectué
# 2.5242326332794818pourcent effectué
# 2.544426494345714pourcent effectué
# 2.5646203554119467pourcent effectué
# 2.5848142164781933pourcent effectué
# 2.6050080775444258pourcent effectué
# 2.6252019386106724pourcent effectué
# 2.6453957996768906pourcent effectué
# 2.6655896607431373pourcent effectué
# 2.6857835218093697pourcent effectué
# 2.705977382875602pourcent effectué
# 2.726171243941849pourcent effectué
# 2.7463651050080813pourcent effectué
# 2.7665589660743137pourcent effectué
# 2.786752827140546pourcent effectué
# 2.806946688206793pourcent effectué
# 2.8271405492730253pourcent effectué
# 2.8473344103392577pourcent effectué
# 2.86752827140549pourcent effectué
# 2.8877221324717226pourcent effectué
# 2.9079159935379693pourcent effectué
# 2.9281098546042017pourcent effectué
# 2.9483037156704484pourcent effectué
# 2.9684975767366666pourcent effectué
# 2.988691437802899pourcent effectué
# 3.0088852988691457pourcent effectué
# 3.029079159935378pourcent effectué
# 3.049273021001625pourcent effectué
# 3.0694668820678572pourcent effectué
# 3.0896607431340897pourcent effectué
# 3.109854604200322pourcent effectué
# 3.1300484652665546pourcent effectué
# 3.150242326332801pourcent effectué
# 3.1704361873990337pourcent effectué
# 3.190630048465266pourcent effectué
# 3.2108239095314985pourcent effectué
# 3.231017770597731pourcent effectué
# 3.2512116316639776pourcent effectué
# 3.27140549273021pourcent effectué
# 3.2915993537964425pourcent effectué
# 3.311793214862675pourcent effectué
# 3.3319870759289216pourcent effectué
# 3.352180936995154pourcent effectué
# 3.3723747980613865pourcent effectué
# 3.392568659127619pourcent effectué
# 3.4127625201938514pourcent effectué
# 3.432956381260098pourcent effectué
# 3.4531502423263305pourcent effectué
# 3.473344103392577pourcent effectué
# 3.4935379644588096pourcent effectué
# 3.513731825525042pourcent effectué
# 3.5339256865912745pourcent effectué
# 3.554119547657507pourcent effectué
# 3.5743134087237536pourcent effectué
# 3.594507269789986pourcent effectué
# 3.6147011308562185pourcent effectué
# 3.634894991922451pourcent effectué
# 3.6550888529886834pourcent effectué
# 3.67528271405493pourcent effectué
# 3.6954765751211625pourcent effectué
# 3.715670436187395pourcent effectué
# 3.7358642972536273pourcent effectué
# 3.756058158319874pourcent effectué
# 3.7762520193861064pourcent effectué
# 3.796445880452339pourcent effectué
# 3.8166397415185855pourcent effectué
# 3.8368336025848038pourcent effectué
# 3.8570274636510504pourcent effectué
# 3.877221324717283pourcent effectué
# 3.8974151857835295pourcent effectué
# 3.917609046849762pourcent effectué
# 3.9378029079159944pourcent effectué
# 3.957996768982227pourcent effectué
# 3.9781906300484593pourcent effectué
# 3.998384491114706pourcent effectué
# 4.018578352180938pourcent effectué
# 4.038772213247171pourcent effectué
# 4.058966074313403pourcent effectué
# 4.079159935379636pourcent effectué
# 4.099353796445882pourcent effectué
# 4.119547657512115pourcent effectué
# 4.1397415185783615pourcent effectué
# 4.15993537964458pourcent effectué
# 4.180129240710826pourcent effectué
# 4.200323101777059pourcent effectué
# 4.220516962843291pourcent effectué
# 4.240710823909538pourcent effectué
# 4.26090468497577pourcent effectué
# 4.281098546042003pourcent effectué
# 4.301292407108235pourcent effectué
# 4.321486268174482pourcent effectué
# 4.341680129240714pourcent effectué
# 4.361873990306947pourcent effectué
# 4.382067851373179pourcent effectué
# 4.402261712439412pourcent effectué
# 4.422455573505658pourcent effectué
# 4.442649434571891pourcent effectué
# 4.462843295638123pourcent effectué
# 4.483037156704356pourcent effectué
# 4.503231017770588pourcent effectué
# 4.523424878836835pourcent effectué
# 4.543618739903067pourcent effectué
# 4.563812600969314pourcent effectué
# 4.584006462035546pourcent effectué
# 4.604200323101779pourcent effectué
# 4.624394184168011pourcent effectué
# 4.644588045234244pourcent effectué
# 4.66478190630049pourcent effectué
# 4.684975767366723pourcent effectué
# 4.705169628432955pourcent effectué
# 4.725363489499188pourcent effectué
# 4.745557350565434pourcent effectué
# 4.765751211631667pourcent effectué
# 4.785945072697899pourcent effectué
# 4.806138933764132pourcent effectué
# 4.826332794830364pourcent effectué
# 4.846526655896611pourcent effectué
# 4.866720516962843pourcent effectué
# 4.88691437802909pourcent effectué
# 4.907108239095308pourcent effectué
# 4.9273021001615405pourcent effectué
# 4.947495961227787pourcent effectué
# 4.96768982229402pourcent effectué
# 4.987883683360266pourcent effectué
# 5.008077544426499pourcent effectué
# 5.028271405492731pourcent effectué
# 5.0484652665589635pourcent effectué
# 5.068659127625196pourcent effectué
# 5.088852988691443pourcent effectué
# 5.109046849757675pourcent effectué
# 5.1292407108239075pourcent effectué
# 5.14943457189014pourcent effectué
# 5.169628432956387pourcent effectué
# 5.189822294022619pourcent effectué
# 5.2100161550888515pourcent effectué
# 5.230210016155084pourcent effectué
# 5.250403877221316pourcent effectué
# 5.270597738287563pourcent effectué
# 5.2907915993537955pourcent effectué
# 5.310985460420042pourcent effectué
# 5.331179321486275pourcent effectué
# 5.351373182552493pourcent effectué
# 5.3715670436187395pourcent effectué
# 5.391760904684972pourcent effectué
# 5.411954765751219pourcent effectué
# 5.432148626817451pourcent effectué
# 5.4523424878836835pourcent effectué
# 5.472536348949916pourcent effectué
# 5.492730210016148pourcent effectué
# 5.512924071082395pourcent effectué
# 5.5331179321486275pourcent effectué
# 5.55331179321486pourcent effectué
# 5.573505654281092pourcent effectué
# 5.593699515347339pourcent effectué
# 5.6138933764135714pourcent effectué
# 5.634087237479804pourcent effectué
# 5.6542810985460505pourcent effectué
# 5.674474959612269pourcent effectué
# 5.694668820678515pourcent effectué
# 5.714862681744748pourcent effectué
# 5.7350565428109945pourcent effectué
# 5.755250403877227pourcent effectué
# 5.775444264943445pourcent effectué
# 5.795638126009692pourcent effectué
# 5.815831987075924pourcent effectué
# 5.836025848142171pourcent effectué
# 5.856219709208403pourcent effectué
# 5.876413570274636pourcent effectué
# 5.896607431340868pourcent effectué
# 5.916801292407101pourcent effectué
# 5.936995153473347pourcent effectué
# 5.95718901453958pourcent effectué
# 5.977382875605812pourcent effectué
# 5.997576736672045pourcent effectué
# 6.017770597738291pourcent effectué
# 6.037964458804524pourcent effectué
# 6.058158319870756pourcent effectué
# 6.078352180937003pourcent effectué
# 6.098546042003221pourcent effectué
# 6.118739903069468pourcent effectué
# 6.1389337641357pourcent effectué
# 6.159127625201947pourcent effectué
# 6.179321486268179pourcent effectué
# 6.199515347334412pourcent effectué
# 6.219709208400644pourcent effectué
# 6.239903069466877pourcent effectué
# 6.260096930533123pourcent effectué
# 6.280290791599356pourcent effectué
# 6.300484652665588pourcent effectué
# 6.320678513731821pourcent effectué
# 6.340872374798053pourcent effectué
# 6.3610662358643pourcent effectué
# 6.381260096930532pourcent effectué
# 6.401453957996779pourcent effectué
# 6.421647819062997pourcent effectué
# 6.441841680129244pourcent effectué
# 6.462035541195476pourcent effectué
# 6.482229402261709pourcent effectué
# 6.502423263327955pourcent effectué
# 6.522617124394188pourcent effectué
# 6.54281098546042pourcent effectué
# 6.563004846526653pourcent effectué
# 6.583198707592899pourcent effectué
# 6.603392568659132pourcent effectué
# 6.623586429725364pourcent effectué
# 6.643780290791597pourcent effectué
# 6.663974151857829pourcent effectué
# 6.684168012924076pourcent effectué
# 6.704361873990308pourcent effectué
# 6.724555735056555pourcent effectué
# 6.744749596122773pourcent effectué
# 6.7649434571890055pourcent effectué
# 6.785137318255252pourcent effectué
# 6.805331179321485pourcent effectué
# 6.825525040387731pourcent effectué
# 6.8457189014539495pourcent effectué
# 6.865912762520196pourcent effectué
# 6.8861066235864286pourcent effectué
# 6.906300484652661pourcent effectué
# 6.926494345718908pourcent effectué
# 6.94668820678514pourcent effectué
# 6.9668820678513725pourcent effectué
# 6.987075928917605pourcent effectué
# 7.007269789983852pourcent effectué
# 7.027463651050084pourcent effectué
# 7.0476575121163165pourcent effectué
# 7.067851373182549pourcent effectué
# 7.088045234248781pourcent effectué
# 7.108239095315028pourcent effectué
# 7.1284329563812605pourcent effectué
# 7.148626817447507pourcent effectué
# 7.168820678513725pourcent effectué
# 7.189014539579958pourcent effectué
# 7.2092084006462045pourcent effectué
# 7.229402261712437pourcent effectué
# 7.249596122778684pourcent effectué
# 7.269789983844916pourcent effectué
# 7.2899838449111485pourcent effectué
# 7.310177705977381pourcent effectué
# 7.330371567043613pourcent effectué
# 7.35056542810986pourcent effectué
# 7.3707592891760925pourcent effectué
# 7.390953150242325pourcent effectué
# 7.411147011308557pourcent effectué
# 7.431340872374804pourcent effectué
# 7.4515347334410365pourcent effectué
# 7.471728594507269pourcent effectué
# 7.491922455573501pourcent effectué
# 7.512116316639734pourcent effectué
# 7.53231017770598pourcent effectué
# 7.552504038772213pourcent effectué
# 7.5726978998384595pourcent effectué
# 7.592891760904692pourcent effectué
# 7.61308562197091pourcent effectué
# 7.633279483037157pourcent effectué
# 7.653473344103389pourcent effectué
# 7.673667205169636pourcent effectué
# 7.693861066235868pourcent effectué
# 7.714054927302101pourcent effectué
# 7.734248788368333pourcent effectué
# 7.754442649434566pourcent effectué
# 7.774636510500812pourcent effectué
# 7.794830371567045pourcent effectué
# 7.815024232633277pourcent effectué
# 7.83521809369951pourcent effectué
# 7.855411954765756pourcent effectué
# 7.875605815831989pourcent effectué
# 7.895799676898221pourcent effectué
# 7.915993537964454pourcent effectué
# 7.936187399030686pourcent effectué
# 7.956381260096933pourcent effectué
# 7.976575121163165pourcent effectué
# 7.996768982229412pourcent effectué
# 8.016962843295644pourcent effectué
# 8.037156704361877pourcent effectué
# 8.05735056542811pourcent effectué
# 8.077544426494342pourcent effectué
# 8.097738287560588pourcent effectué
# 8.11793214862682pourcent effectué
# 8.138126009693053pourcent effectué
# 8.158319870759286pourcent effectué
# 8.178513731825518pourcent effectué
# 8.198707592891765pourcent effectué
# 8.218901453957997pourcent effectué
# 8.23909531502423pourcent effectué
# 8.259289176090462pourcent effectué
# 8.279483037156709pourcent effectué
# 8.299676898222941pourcent effectué
# 8.319870759289174pourcent effectué
# 8.34006462035542pourcent effectué
# 8.360258481421639pourcent effectué
# 8.380452342487885pourcent effectué
# 8.400646203554118pourcent effectué
# 8.420840064620364pourcent effectué
# 8.441033925686597pourcent effectué
# 8.46122778675283pourcent effectué
# 8.481421647819062pourcent effectué
# 8.501615508885294pourcent effectué
# 8.52180936995154pourcent effectué
# 8.542003231017773pourcent effectué
# 8.562197092084006pourcent effectué
# 8.582390953150238pourcent effectué
# 8.60258481421647pourcent effectué
# 8.622778675282717pourcent effectué
# 8.64297253634895pourcent effectué
# 8.663166397415196pourcent effectué
# 8.683360258481414pourcent effectué
# 8.703554119547661pourcent effectué
# 8.723747980613894pourcent effectué
# 8.743941841680126pourcent effectué
# 8.764135702746373pourcent effectué
# 8.784329563812605pourcent effectué
# 8.804523424878838pourcent effectué
# 8.82471728594507pourcent effectué
# 8.844911147011317pourcent effectué
# 8.865105008077549pourcent effectué
# 8.885298869143782pourcent effectué
# 8.905492730210014pourcent effectué
# 8.925686591276246pourcent effectué
# 8.945880452342493pourcent effectué
# 8.966074313408726pourcent effectué
# 8.986268174474958pourcent effectué
# 9.00646203554119pourcent effectué
# 9.026655896607423pourcent effectué
# 9.04684975767367pourcent effectué
# 9.067043618739902pourcent effectué
# 9.087237479806149pourcent effectué
# 9.107431340872381pourcent effectué
# 9.127625201938613pourcent effectué
# 9.147819063004846pourcent effectué
# 9.168012924071078pourcent effectué
# 9.188206785137325pourcent effectué
# 9.208400646203557pourcent effectué
# 9.22859450726979pourcent effectué
# 9.248788368336022pourcent effectué
# 9.268982229402269pourcent effectué
# 9.289176090468501pourcent effectué
# 9.309369951534734pourcent effectué
# 9.329563812600966pourcent effectué
# 9.349757673667199pourcent effectué
# 9.369951534733445pourcent effectué
# 9.390145395799678pourcent effectué
# 9.41033925686591pourcent effectué
# 9.430533117932143pourcent effectué
# 9.450726978998375pourcent effectué
# 9.470920840064622pourcent effectué
# 9.491114701130854pourcent effectué
# 9.511308562197101pourcent effectué
# 9.531502423263333pourcent effectué
# 9.551696284329552pourcent effectué
# 9.571890145395798pourcent effectué
# 9.59208400646203pourcent effectué
# 9.612277867528277pourcent effectué
# 9.63247172859451pourcent effectué
# 9.652665589660742pourcent effectué
# 9.672859450726975pourcent effectué
# 9.693053311793207pourcent effectué
# 9.713247172859454pourcent effectué
# 9.733441033925686pourcent effectué
# 9.753634894991919pourcent effectué
# 9.773828756058151pourcent effectué
# 9.794022617124398pourcent effectué
# 9.81421647819063pourcent effectué
# 9.834410339256863pourcent effectué
# 9.85460420032311pourcent effectué
# 9.874798061389328pourcent effectué
# 9.894991922455574pourcent effectué
# 9.915185783521807pourcent effectué
# 9.935379644588053pourcent effectué
# 9.955573505654286pourcent effectué
# 9.975767366720518pourcent effectué
# 9.99596122778675pourcent effectué
# 10.016155088852983pourcent effectué
# 10.03634894991923pourcent effectué
# 10.056542810985462pourcent effectué
# 10.076736672051695pourcent effectué
# 10.096930533117927pourcent effectué
# 10.11712439418416pourcent effectué
# 10.137318255250406pourcent effectué
# 10.157512116316639pourcent effectué
# 10.177705977382885pourcent effectué
# 10.197899838449104pourcent effectué
# 10.21809369951535pourcent effectué
# 10.238287560581583pourcent effectué
# 10.258481421647815pourcent effectué
# 10.278675282714062pourcent effectué
# 10.29886914378028pourcent effectué
# 10.319063004846527pourcent effectué
# 10.339256865912759pourcent effectué
# 10.359450726979006pourcent effectué
# 10.379644588045238pourcent effectué
# 10.39983844911147pourcent effectué
# 10.420032310177703pourcent effectué
# 10.440226171243935pourcent effectué
# 10.460420032310182pourcent effectué
# 10.480613893376415pourcent effectué
# 10.500807754442647pourcent effectué
# 10.52100161550888pourcent effectué
# 10.541195476575112pourcent effectué
# 10.561389337641359pourcent effectué
# 10.581583198707591pourcent effectué
# 10.601777059773838pourcent effectué
# 10.621970920840056pourcent effectué
# 10.642164781906303pourcent effectué
# 10.662358642972535pourcent effectué
# 10.682552504038767pourcent effectué
# 10.702746365105014pourcent effectué
# 10.722940226171247pourcent effectué
# 10.743134087237479pourcent effectué
# 10.763327948303711pourcent effectué
# 10.783521809369958pourcent effectué
# 10.80371567043619pourcent effectué
# 10.823909531502423pourcent effectué
# 10.844103392568655pourcent effectué
# 10.864297253634888pourcent effectué
# 10.884491114701135pourcent effectué
# 10.904684975767367pourcent effectué
# 10.924878836833614pourcent effectué
# 10.945072697899832pourcent effectué
# 10.965266558966064pourcent effectué
# 10.985460420032311pourcent effectué
# 11.005654281098543pourcent effectué
# 11.02584814216479pourcent effectué
# 11.046042003231022pourcent effectué
# 11.066235864297255pourcent effectué
# 11.086429725363487pourcent effectué
# 11.10662358642972pourcent effectué
# 11.126817447495966pourcent effectué
# 11.147011308562199pourcent effectué
# 11.167205169628431pourcent effectué
# 11.187399030694664pourcent effectué
# 11.20759289176091pourcent effectué
# 11.227786752827143pourcent effectué
# 11.247980613893375pourcent effectué
# 11.268174474959608pourcent effectué
# 11.28836833602584pourcent effectué
# 11.308562197092087pourcent effectué
# 11.32875605815832pourcent effectué
# 11.348949919224566pourcent effectué
# 11.369143780290784pourcent effectué
# 11.389337641357017pourcent effectué
# 11.409531502423263pourcent effectué
# 11.429725363489496pourcent effectué
# 11.449919224555742pourcent effectué
# 11.470113085621975pourcent effectué
# 11.490306946688207pourcent effectué
# 11.51050080775444pourcent effectué
# 11.530694668820672pourcent effectué
# 11.550888529886919pourcent effectué
# 11.571082390953151pourcent effectué
# 11.591276252019384pourcent effectué
# 11.611470113085616pourcent effectué
# 11.631663974151863pourcent effectué
# 11.651857835218095pourcent effectué
# 11.672051696284328pourcent effectué
# 11.69224555735056pourcent effectué
# 11.712439418416793pourcent effectué
# 11.73263327948304pourcent effectué
# 11.752827140549272pourcent effectué
# 11.773021001615518pourcent effectué
# 11.79321486268175pourcent effectué
# 11.813408723747969pourcent effectué
# 11.833602584814216pourcent effectué
# 11.853796445880448pourcent effectué
# 11.873990306946695pourcent effectué
# 11.894184168012927pourcent effectué
# 11.91437802907916pourcent effectué
# 11.934571890145392pourcent effectué
# 11.954765751211625pourcent effectué
# 11.974959612277871pourcent effectué
# 11.995153473344104pourcent effectué
# 12.015347334410336pourcent effectué
# 12.035541195476569pourcent effectué
# 12.055735056542815pourcent effectué
# 12.075928917609048pourcent effectué
# 12.09612277867528pourcent effectué
# 12.116316639741527pourcent effectué
# 12.136510500807745pourcent effectué
# 12.156704361873992pourcent effectué
# 12.176898222940224pourcent effectué
# 12.19709208400647pourcent effectué
# 12.217285945072703pourcent effectué
# 12.237479806138936pourcent effectué
# 12.257673667205168pourcent effectué
# 12.2778675282714pourcent effectué
# 12.298061389337647pourcent effectué
# 12.31825525040388pourcent effectué
# 12.338449111470112pourcent effectué
# 12.358642972536344pourcent effectué
# 12.378836833602577pourcent effectué
# 12.399030694668824pourcent effectué
# 12.419224555735056pourcent effectué
# 12.439418416801288pourcent effectué
# 12.459612277867521pourcent effectué
# 12.479806138933768pourcent effectué
# 12.5pourcent effectué
# 12.520193861066232pourcent effectué
# 12.540387722132479pourcent effectué
# 12.560581583198712pourcent effectué
# 12.580775444264944pourcent effectué
# 12.600969305331176pourcent effectué
# 12.621163166397423pourcent effectué
# 12.641357027463656pourcent effectué
# 12.661550888529888pourcent effectué
# 12.68174474959612pourcent effectué
# 12.701938610662353pourcent effectué
# 12.7221324717286pourcent effectué
# 12.742326332794832pourcent effectué
# 12.762520193861064pourcent effectué
# 12.782714054927297pourcent effectué
# 12.80290791599353pourcent effectué
# 12.823101777059776pourcent effectué
# 12.843295638126008pourcent effectué
# 12.863489499192255pourcent effectué
# 12.883683360258473pourcent effectué
# 12.90387722132472pourcent effectué
# 12.924071082390952pourcent effectué
# 12.944264943457185pourcent effectué
# 12.964458804523431pourcent effectué
# 12.984652665589664pourcent effectué
# 13.004846526655896pourcent effectué
# 13.025040387722129pourcent effectué
# 13.045234248788375pourcent effectué
# 13.065428109854608pourcent effectué
# 13.08562197092084pourcent effectué
# 13.105815831987073pourcent effectué
# 13.126009693053305pourcent effectué
# 13.146203554119552pourcent effectué
# 13.166397415185784pourcent effectué
# 13.186591276252031pourcent effectué
# 13.20678513731825pourcent effectué
# 13.226978998384482pourcent effectué
# 13.247172859450728pourcent effectué
# 13.26736672051696pourcent effectué
# 13.287560581583207pourcent effectué
# 13.30775444264944pourcent effectué
# 13.327948303715672pourcent effectué
# 13.348142164781905pourcent effectué
# 13.368336025848137pourcent effectué
# 13.388529886914384pourcent effectué
# 13.408723747980616pourcent effectué
# 13.428917609046849pourcent effectué
# 13.449111470113081pourcent effectué
# 13.469305331179328pourcent effectué
# 13.48949919224556pourcent effectué
# 13.509693053311793pourcent effectué
# 13.529886914378025pourcent effectué
# 13.550080775444258pourcent effectué
# 13.570274636510504pourcent effectué
# 13.590468497576737pourcent effectué
# 13.610662358642983pourcent effectué
# 13.630856219709216pourcent effectué
# 13.651050080775434pourcent effectué
# 13.67124394184168pourcent effectué
# 13.691437802907913pourcent effectué
# 13.71163166397416pourcent effectué
# 13.731825525040392pourcent effectué
# 13.752019386106625pourcent effectué
# 13.772213247172857pourcent effectué
# 13.79240710823909pourcent effectué
# 13.812600969305336pourcent effectué
# 13.832794830371569pourcent effectué
# 13.852988691437801pourcent effectué
# 13.873182552504034pourcent effectué
# 13.89337641357028pourcent effectué
# 13.913570274636513pourcent effectué
# 13.933764135702745pourcent effectué
# 13.953957996768978pourcent effectué
# 13.97415185783521pourcent effectué
# 13.994345718901457pourcent effectué
# 14.014539579967689pourcent effectué
# 14.034733441033936pourcent effectué
# 14.054927302100168pourcent effectué
# 14.075121163166386pourcent effectué
# 14.095315024232633pourcent effectué
# 14.115508885298865pourcent effectué
# 14.135702746365112pourcent effectué
# 14.155896607431345pourcent effectué
# 14.176090468497577pourcent effectué
# 14.19628432956381pourcent effectué
# 14.216478190630042pourcent effectué
# 14.236672051696289pourcent effectué
# 14.256865912762521pourcent effectué
# 14.277059773828753pourcent effectué
# 14.297253634894986pourcent effectué
# 14.317447495961233pourcent effectué
# 14.337641357027465pourcent effectué
# 14.357835218093697pourcent effectué
# 14.378029079159944pourcent effectué
# 14.398222940226162pourcent effectué
# 14.418416801292409pourcent effectué
# 14.438610662358641pourcent effectué
# 14.458804523424888pourcent effectué
# 14.47899838449112pourcent effectué
# 14.499192245557353pourcent effectué
# 14.519386106623585pourcent effectué
# 14.539579967689818pourcent effectué
# 14.559773828756065pourcent effectué
# 14.579967689822297pourcent effectué
# 14.60016155088853pourcent effectué
# 14.620355411954762pourcent effectué
# 14.640549273020994pourcent effectué
# 14.660743134087241pourcent effectué
# 14.680936995153473pourcent effectué
# 14.70113085621972pourcent effectué
# 14.721324717285938pourcent effectué
# 14.741518578352185pourcent effectué
# 14.761712439418417pourcent effectué
# 14.78190630048465pourcent effectué
# 14.802100161550896pourcent effectué
# 14.822294022617115pourcent effectué
# 14.842487883683361pourcent effectué
# 14.862681744749594pourcent effectué
# 14.88287560581584pourcent effectué
# 14.903069466882073pourcent effectué
# 14.923263327948305pourcent effectué
# 14.943457189014538pourcent effectué
# 14.96365105008077pourcent effectué
# 14.983844911147017pourcent effectué
# 15.00403877221325pourcent effectué
# 15.024232633279482pourcent effectué
# 15.044426494345714pourcent effectué
# 15.064620355411947pourcent effectué
# 15.084814216478193pourcent effectué
# 15.105008077544426pourcent effectué
# 15.125201938610672pourcent effectué
# 15.14539579967689pourcent effectué
# 15.165589660743137pourcent effectué
# 15.18578352180937pourcent effectué
# 15.205977382875602pourcent effectué
# 15.226171243941849pourcent effectué
# 15.246365105008081pourcent effectué
# 15.266558966074314pourcent effectué
# 15.286752827140546pourcent effectué
# 15.306946688206793pourcent effectué
# 15.327140549273025pourcent effectué
# 15.347334410339258pourcent effectué
# 15.36752827140549pourcent effectué
# 15.387722132471723pourcent effectué
# 15.40791599353797pourcent effectué
# 15.428109854604202pourcent effectué
# 15.448303715670448pourcent effectué
# 15.468497576736667pourcent effectué
# 15.488691437802899pourcent effectué
# 15.508885298869146pourcent effectué
# 15.529079159935378pourcent effectué
# 15.549273021001625pourcent effectué
# 15.569466882067857pourcent effectué
# 15.58966074313409pourcent effectué
# 15.609854604200322pourcent effectué
# 15.630048465266555pourcent effectué
# 15.650242326332801pourcent effectué
# 15.670436187399034pourcent effectué
# 15.690630048465266pourcent effectué
# 15.710823909531499pourcent effectué
# 15.731017770597731pourcent effectué
# 15.751211631663978pourcent effectué
# 15.77140549273021pourcent effectué
# 15.791599353796443pourcent effectué
# 15.811793214862675pourcent effectué
# 15.831987075928922pourcent effectué
# 15.852180936995154pourcent effectué
# 15.872374798061387pourcent effectué
# 15.892568659127619pourcent effectué
# 15.912762520193851pourcent effectué
# 15.932956381260098pourcent effectué
# 15.95315024232633pourcent effectué
# 15.973344103392577pourcent effectué
# 15.99353796445881pourcent effectué
# 16.013731825525042pourcent effectué
# 16.033925686591274pourcent effectué
# 16.054119547657507pourcent effectué
# 16.074313408723754pourcent effectué
# 16.094507269789986pourcent effectué
# 16.11470113085622pourcent effectué
# 16.13489499192245pourcent effectué
# 16.155088852988683pourcent effectué
# 16.17528271405493pourcent effectué
# 16.195476575121162pourcent effectué
# 16.215670436187395pourcent effectué
# 16.235864297253627pourcent effectué
# 16.256058158319874pourcent effectué
# 16.276252019386106pourcent effectué
# 16.29644588045234pourcent effectué
# 16.316639741518586pourcent effectué
# 16.336833602584804pourcent effectué
# 16.35702746365105pourcent effectué
# 16.377221324717283pourcent effectué
# 16.39741518578353pourcent effectué
# 16.417609046849762pourcent effectué
# 16.437802907915994pourcent effectué
# 16.457996768982227pourcent effectué
# 16.47819063004846pourcent effectué
# 16.498384491114706pourcent effectué
# 16.51857835218094pourcent effectué
# 16.53877221324717pourcent effectué
# 16.558966074313403pourcent effectué
# 16.579159935379636pourcent effectué
# 16.599353796445882pourcent effectué
# 16.619547657512115pourcent effectué
# 16.63974151857836pourcent effectué
# 16.65993537964458pourcent effectué
# 16.680129240710826pourcent effectué
# 16.70032310177706pourcent effectué
# 16.72051696284329pourcent effectué
# 16.740710823909538pourcent effectué
# 16.76090468497577pourcent effectué
# 16.781098546042003pourcent effectué
# 16.801292407108235pourcent effectué
# 16.821486268174482pourcent effectué
# 16.841680129240714pourcent effectué
# 16.861873990306947pourcent effectué
# 16.88206785137318pourcent effectué
# 16.90226171243941pourcent effectué
# 16.92245557350566pourcent effectué
# 16.94264943457189pourcent effectué
# 16.962843295638123pourcent effectué
# 16.983037156704356pourcent effectué
# 17.003231017770588pourcent effectué
# 17.023424878836835pourcent effectué
# 17.043618739903067pourcent effectué
# 17.063812600969314pourcent effectué
# 17.084006462035546pourcent effectué
# 17.10420032310178pourcent effectué
# 17.12439418416801pourcent effectué
# 17.144588045234244pourcent effectué
# 17.16478190630049pourcent effectué
# 17.184975767366723pourcent effectué
# 17.205169628432955pourcent effectué
# 17.225363489499188pourcent effectué
# 17.245557350565434pourcent effectué
# 17.265751211631667pourcent effectué
# 17.2859450726979pourcent effectué
# 17.30613893376413pourcent effectué
# 17.326332794830364pourcent effectué
# 17.34652665589661pourcent effectué
# 17.366720516962843pourcent effectué
# 17.38691437802909pourcent effectué
# 17.407108239095308pourcent effectué
# 17.42730210016154pourcent effectué
# 17.447495961227787pourcent effectué
# 17.46768982229402pourcent effectué
# 17.487883683360266pourcent effectué
# 17.5080775444265pourcent effectué
# 17.52827140549273pourcent effectué
# 17.548465266558964pourcent effectué
# 17.568659127625196pourcent effectué
# 17.588852988691443pourcent effectué
# 17.609046849757675pourcent effectué
# 17.629240710823908pourcent effectué
# 17.64943457189014pourcent effectué
# 17.669628432956387pourcent effectué
# 17.68982229402262pourcent effectué
# 17.71001615508885pourcent effectué
# 17.730210016155084pourcent effectué
# 17.750403877221316pourcent effectué
# 17.770597738287563pourcent effectué
# 17.790791599353796pourcent effectué
# 17.810985460420042pourcent effectué
# 17.831179321486275pourcent effectué
# 17.851373182552493pourcent effectué
# 17.87156704361874pourcent effectué
# 17.891760904684972pourcent effectué
# 17.91195476575122pourcent effectué
# 17.93214862681745pourcent effectué
# 17.952342487883683pourcent effectué
# 17.972536348949916pourcent effectué
# 17.99273021001615pourcent effectué
# 18.012924071082395pourcent effectué
# 18.033117932148627pourcent effectué
# 18.05331179321486pourcent effectué
# 18.073505654281092pourcent effectué
# 18.09369951534734pourcent effectué
# 18.11389337641357pourcent effectué
# 18.134087237479804pourcent effectué
# 18.15428109854605pourcent effectué
# 18.17447495961227pourcent effectué
# 18.194668820678515pourcent effectué
# 18.214862681744748pourcent effectué
# 18.235056542810995pourcent effectué
# 18.255250403877227pourcent effectué
# 18.275444264943445pourcent effectué
# 18.295638126009692pourcent effectué
# 18.315831987075924pourcent effectué
# 18.33602584814217pourcent effectué
# 18.356219709208403pourcent effectué
# 18.376413570274636pourcent effectué
# 18.39660743134087pourcent effectué
# 18.4168012924071pourcent effectué
# 18.436995153473347pourcent effectué
# 18.45718901453958pourcent effectué
# 18.477382875605812pourcent effectué
# 18.497576736672045pourcent effectué
# 18.51777059773829pourcent effectué
# 18.537964458804524pourcent effectué
# 18.558158319870756pourcent effectué
# 18.578352180937003pourcent effectué
# 18.59854604200322pourcent effectué
# 18.618739903069468pourcent effectué
# 18.6389337641357pourcent effectué
# 18.659127625201947pourcent effectué
# 18.67932148626818pourcent effectué
# 18.699515347334412pourcent effectué
# 18.719709208400644pourcent effectué
# 18.739903069466877pourcent effectué
# 18.760096930533123pourcent effectué
# 18.780290791599356pourcent effectué
# 18.800484652665588pourcent effectué
# 18.82067851373182pourcent effectué
# 18.840872374798053pourcent effectué
# 18.8610662358643pourcent effectué
# 18.881260096930532pourcent effectué
# 18.90145395799678pourcent effectué
# 18.921647819062997pourcent effectué
# 18.941841680129244pourcent effectué
# 18.962035541195476pourcent effectué
# 18.98222940226171pourcent effectué
# 19.002423263327955pourcent effectué
# 19.022617124394188pourcent effectué
# 19.04281098546042pourcent effectué
# 19.063004846526653pourcent effectué
# 19.0831987075929pourcent effectué
# 19.10339256865913pourcent effectué
# 19.123586429725364pourcent effectué
# 19.143780290791597pourcent effectué
# 19.16397415185783pourcent effectué
# 19.184168012924076pourcent effectué
# 19.204361873990308pourcent effectué
# 19.224555735056555pourcent effectué
# 19.244749596122773pourcent effectué
# 19.264943457189005pourcent effectué
# 19.285137318255252pourcent effectué
# 19.305331179321485pourcent effectué
# 19.32552504038773pourcent effectué
# 19.34571890145395pourcent effectué
# 19.365912762520196pourcent effectué
# 19.38610662358643pourcent effectué
# 19.40630048465266pourcent effectué
# 19.426494345718908pourcent effectué
# 19.44668820678514pourcent effectué
# 19.466882067851373pourcent effectué
# 19.487075928917605pourcent effectué
# 19.50726978998385pourcent effectué
# 19.527463651050084pourcent effectué
# 19.547657512116317pourcent effectué
# 19.56785137318255pourcent effectué
# 19.58804523424878pourcent effectué
# 19.608239095315028pourcent effectué
# 19.62843295638126pourcent effectué
# 19.648626817447507pourcent effectué
# 19.668820678513725pourcent effectué
# 19.689014539579958pourcent effectué
# 19.709208400646204pourcent effectué
# 19.729402261712437pourcent effectué
# 19.749596122778684pourcent effectué
# 19.769789983844916pourcent effectué
# 19.78998384491115pourcent effectué
# 19.81017770597738pourcent effectué
# 19.830371567043613pourcent effectué
# 19.85056542810986pourcent effectué
# 19.870759289176092pourcent effectué
# 19.890953150242325pourcent effectué
# 19.911147011308557pourcent effectué
# 19.931340872374804pourcent effectué
# 19.951534733441036pourcent effectué
# 19.97172859450727pourcent effectué
# 19.9919224555735pourcent effectué
# 20.012116316639734pourcent effectué
# 20.03231017770598pourcent effectué
# 20.052504038772213pourcent effectué
# 20.07269789983846pourcent effectué
# 20.092891760904692pourcent effectué
# 20.11308562197091pourcent effectué
# 20.133279483037157pourcent effectué
# 20.15347334410339pourcent effectué
# 20.173667205169636pourcent effectué
# 20.19386106623587pourcent effectué
# 20.2140549273021pourcent effectué
# 20.234248788368333pourcent effectué
# 20.254442649434566pourcent effectué
# 20.274636510500812pourcent effectué
# 20.294830371567045pourcent effectué
# 20.315024232633277pourcent effectué
# 20.33521809369951pourcent effectué
# 20.355411954765756pourcent effectué
# 20.37560581583199pourcent effectué
# 20.39579967689822pourcent effectué
# 20.415993537964454pourcent effectué
# 20.436187399030686pourcent effectué
# 20.456381260096933pourcent effectué
# 20.476575121163165pourcent effectué
# 20.496768982229412pourcent effectué
# 20.516962843295644pourcent effectué
# 20.537156704361877pourcent effectué
# 20.55735056542811pourcent effectué
# 20.57754442649434pourcent effectué
# 20.59773828756059pourcent effectué
# 20.61793214862682pourcent effectué
# 20.638126009693053pourcent effectué
# 20.658319870759286pourcent effectué
# 20.678513731825518pourcent effectué
# 20.698707592891765pourcent effectué
# 20.718901453957997pourcent effectué
# 20.73909531502423pourcent effectué
# 20.759289176090462pourcent effectué
# 20.77948303715671pourcent effectué
# 20.79967689822294pourcent effectué
# 20.819870759289174pourcent effectué
# 20.84006462035542pourcent effectué
# 20.86025848142164pourcent effectué
# 20.880452342487885pourcent effectué
# 20.900646203554118pourcent effectué
# 20.920840064620364pourcent effectué
# 20.941033925686597pourcent effectué
# 20.96122778675283pourcent effectué
# 20.98142164781906pourcent effectué
# 21.001615508885294pourcent effectué
# 21.02180936995154pourcent effectué
# 21.042003231017773pourcent effectué
# 21.062197092084006pourcent effectué
# 21.082390953150238pourcent effectué
# 21.10258481421647pourcent effectué
# 21.122778675282717pourcent effectué
# 21.14297253634895pourcent effectué
# 21.163166397415196pourcent effectué
# 21.183360258481414pourcent effectué
# 21.20355411954766pourcent effectué
# 21.223747980613894pourcent effectué
# 21.243941841680126pourcent effectué
# 21.264135702746373pourcent effectué
# 21.284329563812605pourcent effectué
# 21.304523424878838pourcent effectué
# 21.32471728594507pourcent effectué
# 21.344911147011317pourcent effectué
# 21.36510500807755pourcent effectué
# 21.38529886914378pourcent effectué
# 21.405492730210014pourcent effectué
# 21.425686591276246pourcent effectué
# 21.445880452342493pourcent effectué
# 21.466074313408726pourcent effectué
# 21.486268174474958pourcent effectué
# 21.50646203554119pourcent effectué
# 21.526655896607423pourcent effectué
# 21.54684975767367pourcent effectué
# 21.567043618739902pourcent effectué
# 21.58723747980615pourcent effectué
# 21.60743134087238pourcent effectué
# 21.627625201938613pourcent effectué
# 21.647819063004846pourcent effectué
# 21.66801292407108pourcent effectué
# 21.688206785137325pourcent effectué
# 21.708400646203557pourcent effectué
# 21.72859450726979pourcent effectué
# 21.748788368336022pourcent effectué
# 21.76898222940227pourcent effectué
# 21.7891760904685pourcent effectué
# 21.809369951534734pourcent effectué
# 21.829563812600966pourcent effectué
# 21.8497576736672pourcent effectué
# 21.869951534733445pourcent effectué
# 21.890145395799678pourcent effectué
# 21.91033925686591pourcent effectué
# 21.930533117932143pourcent effectué
# 21.950726978998375pourcent effectué
# 21.970920840064622pourcent effectué
# 21.991114701130854pourcent effectué
# 22.0113085621971pourcent effectué
# 22.031502423263333pourcent effectué
# 22.05169628432955pourcent effectué
# 22.0718901453958pourcent effectué
# 22.09208400646203pourcent effectué
# 22.112277867528277pourcent effectué
# 22.13247172859451pourcent effectué
# 22.152665589660742pourcent effectué
# 22.172859450726975pourcent effectué
# 22.193053311793207pourcent effectué
# 22.213247172859454pourcent effectué
# 22.233441033925686pourcent effectué
# 22.25363489499192pourcent effectué
# 22.27382875605815pourcent effectué
# 22.294022617124398pourcent effectué
# 22.31421647819063pourcent effectué
# 22.334410339256863pourcent effectué
# 22.35460420032311pourcent effectué
# 22.374798061389328pourcent effectué
# 22.394991922455574pourcent effectué
# 22.415185783521807pourcent effectué
# 22.435379644588053pourcent effectué
# 22.455573505654286pourcent effectué
# 22.47576736672052pourcent effectué
# 22.49596122778675pourcent effectué
# 22.516155088852983pourcent effectué
# 22.53634894991923pourcent effectué
# 22.556542810985462pourcent effectué
# 22.576736672051695pourcent effectué
# 22.596930533117927pourcent effectué
# 22.61712439418416pourcent effectué
# 22.637318255250406pourcent effectué
# 22.65751211631664pourcent effectué
# 22.677705977382885pourcent effectué
# 22.697899838449104pourcent effectué
# 22.71809369951535pourcent effectué
# 22.738287560581583pourcent effectué
# 22.758481421647815pourcent effectué
# 22.77867528271406pourcent effectué
# 22.79886914378028pourcent effectué
# 22.819063004846527pourcent effectué
# 22.83925686591276pourcent effectué
# 22.859450726979006pourcent effectué
# 22.879644588045238pourcent effectué
# 22.89983844911147pourcent effectué
# 22.920032310177703pourcent effectué
# 22.940226171243935pourcent effectué
# 22.960420032310182pourcent effectué
# 22.980613893376415pourcent effectué
# 23.000807754442647pourcent effectué
# 23.02100161550888pourcent effectué
# 23.041195476575112pourcent effectué
# 23.06138933764136pourcent effectué
# 23.08158319870759pourcent effectué
# 23.101777059773838pourcent effectué
# 23.121970920840056pourcent effectué
# 23.142164781906303pourcent effectué
# 23.162358642972535pourcent effectué
# 23.182552504038767pourcent effectué
# 23.202746365105014pourcent effectué
# 23.222940226171247pourcent effectué
# 23.24313408723748pourcent effectué
# 23.26332794830371pourcent effectué
# 23.283521809369958pourcent effectué
# 23.30371567043619pourcent effectué
# 23.323909531502423pourcent effectué
# 23.344103392568655pourcent effectué
# 23.364297253634888pourcent effectué
# 23.384491114701135pourcent effectué
# 23.404684975767367pourcent effectué
# 23.424878836833614pourcent effectué
# 23.445072697899832pourcent effectué
# 23.465266558966064pourcent effectué
# 23.48546042003231pourcent effectué
# 23.505654281098543pourcent effectué
# 23.52584814216479pourcent effectué
# 23.546042003231022pourcent effectué
# 23.566235864297255pourcent effectué
# 23.586429725363487pourcent effectué
# 23.60662358642972pourcent effectué
# 23.626817447495966pourcent effectué
# 23.6470113085622pourcent effectué
# 23.66720516962843pourcent effectué
# 23.687399030694664pourcent effectué
# 23.70759289176091pourcent effectué
# 23.727786752827143pourcent effectué
# 23.747980613893375pourcent effectué
# 23.768174474959608pourcent effectué
# 23.78836833602584pourcent effectué
# 23.808562197092087pourcent effectué
# 23.82875605815832pourcent effectué
# 23.848949919224566pourcent effectué
# 23.869143780290784pourcent effectué
# 23.889337641357017pourcent effectué
# 23.909531502423263pourcent effectué
# 23.929725363489496pourcent effectué
# 23.949919224555742pourcent effectué
# 23.970113085621975pourcent effectué
# 23.990306946688207pourcent effectué
# 24.01050080775444pourcent effectué
# 24.030694668820672pourcent effectué
# 24.05088852988692pourcent effectué
# 24.07108239095315pourcent effectué
# 24.091276252019384pourcent effectué
# 24.111470113085616pourcent effectué
# 24.131663974151863pourcent effectué
# 24.151857835218095pourcent effectué
# 24.172051696284328pourcent effectué
# 24.19224555735056pourcent effectué
# 24.212439418416793pourcent effectué
# 24.23263327948304pourcent effectué
# 24.25282714054927pourcent effectué
# 24.27302100161552pourcent effectué
# 24.29321486268175pourcent effectué
# 24.31340872374797pourcent effectué
# 24.333602584814216pourcent effectué
# 24.353796445880448pourcent effectué
# 24.373990306946695pourcent effectué
# 24.394184168012927pourcent effectué
# 24.41437802907916pourcent effectué
# 24.434571890145392pourcent effectué
# 24.454765751211625pourcent effectué
# 24.47495961227787pourcent effectué
# 24.495153473344104pourcent effectué
# 24.515347334410336pourcent effectué
# 24.53554119547657pourcent effectué
# 24.555735056542815pourcent effectué
# 24.575928917609048pourcent effectué
# 24.59612277867528pourcent effectué
# 24.616316639741527pourcent effectué
# 24.636510500807745pourcent effectué
# 24.65670436187399pourcent effectué
# 24.676898222940224pourcent effectué
# 24.69709208400647pourcent effectué
# 24.717285945072703pourcent effectué
# 24.737479806138936pourcent effectué
# 24.757673667205168pourcent effectué
# 24.7778675282714pourcent effectué
# 24.798061389337647pourcent effectué
# 24.81825525040388pourcent effectué
# 24.838449111470112pourcent effectué
# 24.858642972536344pourcent effectué
# 24.878836833602577pourcent effectué
# 24.899030694668824pourcent effectué
# 24.919224555735056pourcent effectué
# 24.93941841680129pourcent effectué
# 24.95961227786752pourcent effectué
# 24.979806138933768pourcent effectué
# 25.0pourcent effectué
# 25.020193861066232pourcent effectué
# 25.04038772213248pourcent effectué
# 25.06058158319871pourcent effectué
# 25.080775444264944pourcent effectué
# 25.100969305331176pourcent effectué
# 25.121163166397423pourcent effectué
# 25.141357027463656pourcent effectué
# 25.161550888529888pourcent effectué
# 25.18174474959612pourcent effectué
# 25.201938610662353pourcent effectué
# 25.2221324717286pourcent effectué
# 25.242326332794832pourcent effectué
# 25.262520193861064pourcent effectué
# 25.282714054927297pourcent effectué
# 25.30290791599353pourcent effectué
# 25.323101777059776pourcent effectué
# 25.34329563812601pourcent effectué
# 25.363489499192255pourcent effectué
# 25.383683360258473pourcent effectué
# 25.40387722132472pourcent effectué
# 25.424071082390952pourcent effectué
# 25.444264943457185pourcent effectué
# 25.46445880452343pourcent effectué
# 25.484652665589664pourcent effectué
# 25.504846526655896pourcent effectué
# 25.52504038772213pourcent effectué
# 25.545234248788375pourcent effectué
# 25.565428109854608pourcent effectué
# 25.58562197092084pourcent effectué
# 25.605815831987073pourcent effectué
# 25.626009693053305pourcent effectué
# 25.646203554119552pourcent effectué
# 25.666397415185784pourcent effectué
# 25.68659127625203pourcent effectué
# 25.70678513731825pourcent effectué
# 25.72697899838448pourcent effectué
# 25.74717285945073pourcent effectué
# 25.76736672051696pourcent effectué
# 25.787560581583207pourcent effectué
# 25.80775444264944pourcent effectué
# 25.827948303715672pourcent effectué
# 25.848142164781905pourcent effectué
# 25.868336025848137pourcent effectué
# 25.888529886914384pourcent effectué
# 25.908723747980616pourcent effectué
# 25.92891760904685pourcent effectué
# 25.94911147011308pourcent effectué
# 25.969305331179328pourcent effectué
# 25.98949919224556pourcent effectué
# 26.009693053311793pourcent effectué
# 26.029886914378025pourcent effectué
# 26.050080775444258pourcent effectué
# 26.070274636510504pourcent effectué
# 26.090468497576737pourcent effectué
# 26.110662358642983pourcent effectué
# 26.130856219709216pourcent effectué
# 26.151050080775434pourcent effectué
# 26.17124394184168pourcent effectué
# 26.191437802907913pourcent effectué
# 26.21163166397416pourcent effectué
# 26.231825525040392pourcent effectué
# 26.252019386106625pourcent effectué
# 26.272213247172857pourcent effectué
# 26.29240710823909pourcent effectué
# 26.312600969305336pourcent effectué
# 26.33279483037157pourcent effectué
# 26.3529886914378pourcent effectué
# 26.373182552504034pourcent effectué
# 26.39337641357028pourcent effectué
# 26.413570274636513pourcent effectué
# 26.433764135702745pourcent effectué
# 26.453957996768978pourcent effectué
# 26.47415185783521pourcent effectué
# 26.494345718901457pourcent effectué
# 26.51453957996769pourcent effectué
# 26.534733441033936pourcent effectué
# 26.554927302100168pourcent effectué
# 26.575121163166386pourcent effectué
# 26.595315024232633pourcent effectué
# 26.615508885298865pourcent effectué
# 26.635702746365112pourcent effectué
# 26.655896607431345pourcent effectué
# 26.676090468497577pourcent effectué
# 26.69628432956381pourcent effectué
# 26.716478190630042pourcent effectué
# 26.73667205169629pourcent effectué
# 26.75686591276252pourcent effectué
# 26.777059773828753pourcent effectué
# 26.797253634894986pourcent effectué
# 26.817447495961233pourcent effectué
# 26.837641357027465pourcent effectué
# 26.857835218093697pourcent effectué
# 26.878029079159944pourcent effectué
# 26.898222940226162pourcent effectué
# 26.91841680129241pourcent effectué
# 26.93861066235864pourcent effectué
# 26.958804523424888pourcent effectué
# 26.97899838449112pourcent effectué
# 26.999192245557353pourcent effectué
# 27.019386106623585pourcent effectué
# 27.039579967689818pourcent effectué
# 27.059773828756065pourcent effectué
# 27.079967689822297pourcent effectué
# 27.10016155088853pourcent effectué
# 27.120355411954762pourcent effectué
# 27.140549273020994pourcent effectué
# 27.16074313408724pourcent effectué
# 27.180936995153473pourcent effectué
# 27.20113085621972pourcent effectué
# 27.22132471728594pourcent effectué
# 27.241518578352185pourcent effectué
# 27.261712439418417pourcent effectué
# ...
# {x : 23, y : -46},
# {x : 24, y : -47},
# {x : 20, y : -43},
# {x : 19, y : -42},
# {x : 20, y : -41},
# {x : 20, y : -42},
# {x : 19, y : -41},
# {x : 20, y : -40},
# {x : 19, y : -40},
# {x : 20, y : -39},
# {x : 21, y : -38},
# {x : 22, y : -37},
